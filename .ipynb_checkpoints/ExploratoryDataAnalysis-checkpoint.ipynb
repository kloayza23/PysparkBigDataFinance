# %% [markdown]
# # Advance One of Big Data Project

# %% [markdown]
# This advance contain the following outline:
#
# * Introduction
# * Load Data Set
# * Descriptive Statistics
# * Visualization

# %% [markdown]
# # Introduction

# %% [markdown]
# The purpose of this project is to use the techniques of Big Data, in this case the data set "Death in the Unite State", let to use tecniques of big data as hive, pig, data mining tools, in other.
#
# The data set determine life expectancy and understand how death in the U.S differs from the rest of the world. The data set is composed by 2 file type, csv and json, for this project only csv is going to be considered.
#
# But this advance of project definition, only the file 2015 data is going to be used.

# %% [markdown]
# # Load Data Set

# %%
import pandas as pd
filename = '../dataset/csv/2015_data.csv'
data_source = pd.read_csv(filename, names=names,sep=",",encoding="ISO-8859-1")
items = ['resident_status', 'education_2003_revision','education_reporting_flag', 'month_of_death',         
        'hispanic_origin','hispanic_originrace_recode']
data=data_source.filter(items=items)

# %% [markdown]
# This source of this file contains 2718198 rows, but for sake of presentation, only 1101 rows are going to be considered.

# %% [markdown]
# # Descriptive Statistics

# %%
peek=data.head(5)
print(peek)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# Here, we can see the information of the variables. The data is composed of the following dimension:

# %%
shape=data.shape
print(shape)
# Out:
# (1101, 25)

# %% [markdown]
# To visualize the statistical of the variables

# %%
pd.set_option('display.width', 100)
pd.set_option('precision', 3)
description = data.describe()
print(description)
# Out:
#        resident_status education_2003_revision education_reporting_flag month_of_death  \
# count              562                     339                      181             99
# unique             192                     144                      106             57
# top               F179                     I10                     I500           T509
# freq                45                      20                        7             12
#
#        detail_age_type detail_age age_recode_52        age_recode_27 age_recode_12  \
# count               50         23             9                    4             2
# unique              44         20             8                    4             2
# top               T510        W80           X45  record_condition_10          R068
# freq                 4          2             2                    1             1
#
#        place_of_death_and_decedents_status            ...                  39_cause_recode  \
# ...

# %% [markdown]
# ## Correlation between attributes

# %%
correlations = data.corr(method='pearson')
print(correlations)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Skew of Distribution

# %%
skew = data.skew()
print(skew)
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Histogram

# %%
from matplotlib import pyplot
data["resident_status"].hist()
data["education_2003_revision"].hist()

# %% [markdown]
# ## Density

# %%
data = pd.read_csv(filename, names=names,sep=",",encoding="ISO-8859-1")
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-aa7d9ce62e65> in <module>()
#       1 data = pd.read_csv(filename, names=names,sep=",",encoding="ISO-8859-1")
# ----> 2 data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
#
# ~/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# ...
